# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt

# %%
def load_data(data_dir, img_size=(128,128)):
    images = []
    masks = []

    for img_file in os.listdir(data_dir):
        if '_mask' not in img_file:
            img_path = os.path.join(data_dir, img_file)
            mask_path = os.path.join(data_dir, img_file.replace('.jpg', '_mask.jpg'))
    
            img = load_img(img_path, target_size=img_size)
            mask = load_img(mask_path, target_size=img_size, color_mode='grayscale')
    
            img = img_to_array(img) / 255.0
            mask = img_to_array(mask) / 255.0
    
            images.append(img)
            masks.append(mask)

    return np.array(images), np.array(masks)

# %%
train_dir = '/kaggle/input/unet4321/split_datasets/train'
val_dir = '/kaggle/input/unet4321/split_datasets/val'
test_dir = '/kaggle/input/unet4321/split_datasets/test'

X_train, y_train = load_data(train_dir)
X_val, y_val = load_data(val_dir)
X_test, y_test = load_data(test_dir)

# %%
def build_dilated_unet(input_shape=(128, 128, 3)):
    inputs = layers.Input(input_shape)

    # Encoder
    conv1 = layers.Conv2D(32, 3, activation='relu', padding='same')(inputs)
    conv1 = layers.Conv2D(32, 3, activation='relu', padding='same')(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = layers.Conv2D(64, 3, activation='relu', padding='same')(pool1)
    conv2 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = layers.Conv2D(128, 3, activation='relu', padding='same')(pool2)
    conv3 = layers.Conv2D(128, 3, activation='relu', padding='same', dilation_rate=2)(conv3)  # Dilated Convolution
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = layers.Conv2D(256, 3, activation='relu', padding='same')(pool3)
    conv4 = layers.Conv2D(256, 3, activation='relu', padding='same', dilation_rate=4)(conv4)  # Dilated Convolution

    # Decoder
    up7 = layers.concatenate([layers.Conv2DTranspose(128, 2, strides=(2, 2), padding='same')(conv4), conv3], axis=3)
    conv7 = layers.Conv2D(128, 3, activation='relu', padding='same')(up7)
    conv7 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv7)

    up8 = layers.concatenate([layers.Conv2DTranspose(64, 2, strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = layers.Conv2D(64, 3, activation='relu', padding='same')(up8)
    conv8 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv8)

    up9 = layers.concatenate([layers.Conv2DTranspose(32, 2, strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = layers.Conv2D(32, 3, activation='relu', padding='same')(up9)
    conv9 = layers.Conv2D(32, 3, activation='relu', padding='same')(conv9)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(conv9)

    model = models.Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = build_dilated_unet()
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 128, 128, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 128, 128, 32)   │            896 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 128, 128, 32)   │          9,248 │ conv2d_15[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 64, 64, 32)     │              0 │ conv2d_16[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 64, 64, 64)     │         18,496 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 64, 64, 64)     │         36,928 │ conv2d_17[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 32, 32, 64)     │              0 │ conv2d_18[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_19 (Conv2D)        │ (None, 32, 32, 128)    │         73,856 │ max_pooling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_20 (Conv2D)        │ (None, 32, 32, 128)    │        147,584 │ conv2d_19[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_5           │ (None, 16, 16, 128)    │              0 │ conv2d_20[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_21 (Conv2D)        │ (None, 16, 16, 256)    │        295,168 │ max_pooling2d_5[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_22 (Conv2D)        │ (None, 16, 16, 256)    │        590,080 │ conv2d_21[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 32, 32, 128)    │        131,200 │ conv2d_22[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 32, 32, 256)    │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ conv2d_20[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_23 (Conv2D)        │ (None, 32, 32, 128)    │        295,040 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_24 (Conv2D)        │ (None, 32, 32, 128)    │        147,584 │ conv2d_23[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_4        │ (None, 64, 64, 64)     │         32,832 │ conv2d_24[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 64, 64, 128)    │              0 │ conv2d_transpose_4[0]… │
# │ (Concatenate)             │                        │                │ conv2d_18[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_25 (Conv2D)        │ (None, 64, 64, 64)     │         73,792 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_26 (Conv2D)        │ (None, 64, 64, 64)     │         36,928 │ conv2d_25[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_5        │ (None, 128, 128, 32)   │          8,224 │ conv2d_26[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_5             │ (None, 128, 128, 64)   │              0 │ conv2d_transpose_5[0]… │
# │ (Concatenate)             │                        │                │ conv2d_16[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_27 (Conv2D)        │ (None, 128, 128, 32)   │         18,464 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_28 (Conv2D)        │ (None, 128, 128, 32)   │          9,248 │ conv2d_27[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_29 (Conv2D)        │ (None, 128, 128, 1)    │             33 │ conv2d_28[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,925,601 (7.35 MB)
#  Trainable params: 1,925,601 (7.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def dice_coef(y_true, y_pred, smooth=1e-6):
    t_true = tf.reduce_sum(y_true)
    y_pred = tf.cast(y_pred > 0.5, dtype=tf.int32)
    y_true = tf.cast(y_true, dtype=tf.float32)
    y_pred = tf.cast(y_pred, dtype=tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred)
    intersection = tf.cast(intersection, dtype=tf.float32)

    y_true = tf.reduce_sum(y_true)
    y_pred = tf.reduce_sum(y_pred)

    result = (2.0*(intersection) + smooth) / (y_true + y_pred + smooth)

    return result

def dice_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

def combined_loss(y_true, y_pred, a=0.95):
    logit_loss_value = tf.keras.losses.binary_crossentropy(y_true, y_pred, from_logits=False)

    dice_loss_value = dice_loss(y_true, y_pred)

    return a*dice_loss_value + (1-a)*logit_loss_value

# %%
model.compile(optimizer='adam',
             loss = combined_loss,
             metrics=[dice_coef])

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_dice_coef',
    factor=0.9,
    patience=3,
    min_lr=1e-6,
    mode='max',
    verbose=1
)

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_unet_model.keras',
    monitor='val_dice_coef',
    save_best_only=True,
    mode='max',
    verbose=1
)

# %%
history = model.fit(X_train, y_train,
                    batch_size=16,
                    epochs=50,
                    validation_data=(X_val, y_val),
                    callbacks=[reduce_lr, model_checkpoint])

model.save('dilated_unet_model.keras')

# Evaluate model size based on parameters
def get_model_param_size(model):
    total_params = model.count_params()
    size_in_mb = (total_params * 4) / (1024 ** 2)  # 4 bytes per parameter, converted to MB
    print(f"Model parameter size: {size_in_mb:.2f} MB")
    return size_in_mb

dilated_model_param_size = get_model_param_size(model)

# Measure inference time
def measure_inference_time(model, X_sample):
    import time
    start_time = time.time()
    model.predict(X_sample, batch_size=1)  # Set batch size to 1 for single-sample inference
    end_time = time.time()
    inference_time = (end_time - start_time) / len(X_sample)
    print(f"Inference time per sample: {inference_time:.4f} seconds")
    return inference_time

dilated_inference_time = measure_inference_time(model, X_test[:10])

print(f"Dilated Model Parameter Size: {dilated_model_param_size:.2f} MB")
print(f"Dilated Inference Time: {dilated_inference_time:.4f} seconds/sample")
# Out:
# Epoch 1/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.0063 - loss: 0.9642
# Epoch 1: val_dice_coef improved from -inf to 0.00000, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - dice_coef: 0.0060 - loss: 0.9641 - val_dice_coef: 1.1786e-10 - val_loss: 0.9586 - learning_rate: 0.0010
# Epoch 2/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 1.2680e-10 - loss: 0.9566
# Epoch 2: val_dice_coef did not improve from 0.00000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 1.2678e-10 - loss: 0.9565 - val_dice_coef: 1.1786e-10 - val_loss: 0.9553 - learning_rate: 0.0010
# Epoch 3/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 7.9374e-04 - loss: 0.9536
# Epoch 3: val_dice_coef improved from 0.00000 to 0.30019, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - dice_coef: 0.0021 - loss: 0.9524 - val_dice_coef: 0.3002 - val_loss: 0.6693 - learning_rate: 0.0010
# Epoch 4/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.4700 - loss: 0.5067
# Epoch 4: val_dice_coef improved from 0.30019 to 0.58425, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - dice_coef: 0.4706 - loss: 0.5062 - val_dice_coef: 0.5843 - val_loss: 0.4001 - learning_rate: 0.0010
# Epoch 5/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.6048 - loss: 0.3781
# Epoch 5: val_dice_coef improved from 0.58425 to 0.66316, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - dice_coef: 0.6059 - loss: 0.3771 - val_dice_coef: 0.6632 - val_loss: 0.3239 - learning_rate: 0.0010
# Epoch 6/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.6903 - loss: 0.2964
# Epoch 6: val_dice_coef improved from 0.66316 to 0.68916, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - dice_coef: 0.6911 - loss: 0.2956 - val_dice_coef: 0.6892 - val_loss: 0.2992 - learning_rate: 0.0010
# Epoch 7/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.7110 - loss: 0.2766
# Epoch 7: val_dice_coef did not improve from 0.68916
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.7118 - loss: 0.2758 - val_dice_coef: 0.6708 - val_loss: 0.3173 - learning_rate: 0.0010
# Epoch 8/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.7372 - loss: 0.2515
# Epoch 8: val_dice_coef improved from 0.68916 to 0.69708, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - dice_coef: 0.7372 - loss: 0.2515 - val_dice_coef: 0.6971 - val_loss: 0.2919 - learning_rate: 0.0010
# Epoch 9/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.7580 - loss: 0.2317
# Epoch 9: val_dice_coef did not improve from 0.69708
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.7580 - loss: 0.2317 - val_dice_coef: 0.6817 - val_loss: 0.3067 - learning_rate: 0.0010
# Epoch 10/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.7764 - loss: 0.2140
# Epoch 10: val_dice_coef improved from 0.69708 to 0.69842, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - dice_coef: 0.7760 - loss: 0.2143 - val_dice_coef: 0.6984 - val_loss: 0.2905 - learning_rate: 0.0010
# Epoch 11/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.7672 - loss: 0.2228
# Epoch 11: val_dice_coef did not improve from 0.69842
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.7675 - loss: 0.2225 - val_dice_coef: 0.6955 - val_loss: 0.2933 - learning_rate: 0.0010
# Epoch 12/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.7958 - loss: 0.1954
# Epoch 12: val_dice_coef did not improve from 0.69842
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.7955 - loss: 0.1957 - val_dice_coef: 0.6672 - val_loss: 0.3208 - learning_rate: 0.0010
# Epoch 13/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.7812 - loss: 0.2093
# Epoch 13: val_dice_coef improved from 0.69842 to 0.70136, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - dice_coef: 0.7818 - loss: 0.2087 - val_dice_coef: 0.7014 - val_loss: 0.2879 - learning_rate: 0.0010
# Epoch 14/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8112 - loss: 0.1807
# Epoch 14: val_dice_coef improved from 0.70136 to 0.70370, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - dice_coef: 0.8111 - loss: 0.1808 - val_dice_coef: 0.7037 - val_loss: 0.2861 - learning_rate: 0.0010
# Epoch 15/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.8054 - loss: 0.1862
# Epoch 15: val_dice_coef improved from 0.70370 to 0.72586, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - dice_coef: 0.8056 - loss: 0.1860 - val_dice_coef: 0.7259 - val_loss: 0.2646 - learning_rate: 0.0010
# Epoch 16/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8185 - loss: 0.1737
# Epoch 16: val_dice_coef did not improve from 0.72586
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8186 - loss: 0.1736 - val_dice_coef: 0.7096 - val_loss: 0.2803 - learning_rate: 0.0010
# Epoch 17/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8240 - loss: 0.1685
# Epoch 17: val_dice_coef improved from 0.72586 to 0.73445, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - dice_coef: 0.8241 - loss: 0.1683 - val_dice_coef: 0.7345 - val_loss: 0.2562 - learning_rate: 0.0010
# Epoch 18/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.8362 - loss: 0.1568
# Epoch 18: val_dice_coef improved from 0.73445 to 0.74572, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - dice_coef: 0.8358 - loss: 0.1572 - val_dice_coef: 0.7457 - val_loss: 0.2454 - learning_rate: 0.0010
# Epoch 19/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8386 - loss: 0.1544
# Epoch 19: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8385 - loss: 0.1545 - val_dice_coef: 0.7303 - val_loss: 0.2607 - learning_rate: 0.0010
# Epoch 20/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.8302 - loss: 0.1624
# Epoch 20: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8306 - loss: 0.1620 - val_dice_coef: 0.6967 - val_loss: 0.2929 - learning_rate: 0.0010
# Epoch 21/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.8477 - loss: 0.1457
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
#
# Epoch 21: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8477 - loss: 0.1457 - val_dice_coef: 0.7418 - val_loss: 0.2494 - learning_rate: 0.0010
# Epoch 22/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.8564 - loss: 0.1374
# Epoch 22: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8563 - loss: 0.1375 - val_dice_coef: 0.7377 - val_loss: 0.2537 - learning_rate: 9.0000e-04
# Epoch 23/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.8595 - loss: 0.1344
# Epoch 23: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - dice_coef: 0.8594 - loss: 0.1346 - val_dice_coef: 0.7270 - val_loss: 0.2638 - learning_rate: 9.0000e-04
# Epoch 24/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8636 - loss: 0.1306
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
#
# Epoch 24: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8635 - loss: 0.1306 - val_dice_coef: 0.7231 - val_loss: 0.2682 - learning_rate: 9.0000e-04
# Epoch 25/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8761 - loss: 0.1185
# Epoch 25: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8759 - loss: 0.1188 - val_dice_coef: 0.7186 - val_loss: 0.2726 - learning_rate: 8.1000e-04
# Epoch 26/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.8810 - loss: 0.1139
# Epoch 26: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8807 - loss: 0.1141 - val_dice_coef: 0.7076 - val_loss: 0.2836 - learning_rate: 8.1000e-04
# Epoch 27/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.8795 - loss: 0.1153
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0007290000503417104.
#
# Epoch 27: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8795 - loss: 0.1153 - val_dice_coef: 0.7184 - val_loss: 0.2728 - learning_rate: 8.1000e-04
# Epoch 28/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8807 - loss: 0.1141
# Epoch 28: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8808 - loss: 0.1140 - val_dice_coef: 0.7020 - val_loss: 0.2897 - learning_rate: 7.2900e-04
# Epoch 29/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.8926 - loss: 0.1027
# Epoch 29: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8922 - loss: 0.1031 - val_dice_coef: 0.7047 - val_loss: 0.2864 - learning_rate: 7.2900e-04
# Epoch 30/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8876 - loss: 0.1076
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0006561000715009868.
#
# Epoch 30: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8876 - loss: 0.1076 - val_dice_coef: 0.7300 - val_loss: 0.2616 - learning_rate: 7.2900e-04
# Epoch 31/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8944 - loss: 0.1010
# Epoch 31: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8943 - loss: 0.1011 - val_dice_coef: 0.7151 - val_loss: 0.2764 - learning_rate: 6.5610e-04
# Epoch 32/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.8962 - loss: 0.0993
# Epoch 32: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8962 - loss: 0.0993 - val_dice_coef: 0.7255 - val_loss: 0.2664 - learning_rate: 6.5610e-04
# Epoch 33/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9082 - loss: 0.0878
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0005904900433961303.
#
# Epoch 33: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9080 - loss: 0.0881 - val_dice_coef: 0.7262 - val_loss: 0.2657 - learning_rate: 6.5610e-04
# Epoch 34/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9020 - loss: 0.0938
# Epoch 34: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9021 - loss: 0.0936 - val_dice_coef: 0.7343 - val_loss: 0.2584 - learning_rate: 5.9049e-04
# Epoch 35/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9073 - loss: 0.0887
# Epoch 35: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9073 - loss: 0.0887 - val_dice_coef: 0.7189 - val_loss: 0.2734 - learning_rate: 5.9049e-04
# Epoch 36/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9130 - loss: 0.0833
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0005314410547725857.
#
# Epoch 36: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9128 - loss: 0.0835 - val_dice_coef: 0.7057 - val_loss: 0.2871 - learning_rate: 5.9049e-04
# Epoch 37/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.9128 - loss: 0.0835
# Epoch 37: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9127 - loss: 0.0835 - val_dice_coef: 0.7175 - val_loss: 0.2751 - learning_rate: 5.3144e-04
# Epoch 38/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9140 - loss: 0.0823
# Epoch 38: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9139 - loss: 0.0824 - val_dice_coef: 0.7238 - val_loss: 0.2693 - learning_rate: 5.3144e-04
# Epoch 39/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9169 - loss: 0.0795
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.00047829695977270604.
#
# Epoch 39: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9168 - loss: 0.0796 - val_dice_coef: 0.7438 - val_loss: 0.2498 - learning_rate: 5.3144e-04
# Epoch 40/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.9214 - loss: 0.0752
# Epoch 40: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9213 - loss: 0.0753 - val_dice_coef: 0.7165 - val_loss: 0.2762 - learning_rate: 4.7830e-04
# Epoch 41/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9270 - loss: 0.0699
# Epoch 41: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9268 - loss: 0.0701 - val_dice_coef: 0.7259 - val_loss: 0.2669 - learning_rate: 4.7830e-04
# Epoch 42/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9288 - loss: 0.0681
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0004304672533180565.
#
# Epoch 42: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9286 - loss: 0.0683 - val_dice_coef: 0.7312 - val_loss: 0.2627 - learning_rate: 4.7830e-04
# Epoch 43/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9279 - loss: 0.0690
# Epoch 43: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9279 - loss: 0.0690 - val_dice_coef: 0.7230 - val_loss: 0.2712 - learning_rate: 4.3047e-04
# Epoch 44/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.9327 - loss: 0.0644
# Epoch 44: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9326 - loss: 0.0645 - val_dice_coef: 0.7203 - val_loss: 0.2738 - learning_rate: 4.3047e-04
# Epoch 45/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9286 - loss: 0.0683
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.00038742052274756136.
#
# Epoch 45: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9286 - loss: 0.0683 - val_dice_coef: 0.7148 - val_loss: 0.2793 - learning_rate: 4.3047e-04
# Epoch 46/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9318 - loss: 0.0653
# Epoch 46: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9317 - loss: 0.0653 - val_dice_coef: 0.7125 - val_loss: 0.2831 - learning_rate: 3.8742e-04
# Epoch 47/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9307 - loss: 0.0663
# Epoch 47: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9307 - loss: 0.0663 - val_dice_coef: 0.7110 - val_loss: 0.2842 - learning_rate: 3.8742e-04
# Epoch 48/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9364 - loss: 0.0608
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0003486784757114947.
#
# Epoch 48: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9363 - loss: 0.0609 - val_dice_coef: 0.7216 - val_loss: 0.2731 - learning_rate: 3.8742e-04
# Epoch 49/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.9401 - loss: 0.0573
# Epoch 49: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - dice_coef: 0.9399 - loss: 0.0575 - val_dice_coef: 0.7144 - val_loss: 0.2805 - learning_rate: 3.4868e-04
# Epoch 50/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.9399 - loss: 0.0575
# Epoch 50: val_dice_coef did not improve from 0.74572
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9399 - loss: 0.0575 - val_dice_coef: 0.7187 - val_loss: 0.2764 - learning_rate: 3.4868e-04
# Model parameter size: 7.35 MB
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Inference time per sample: 0.0472 seconds
# Dilated Model Parameter Size: 7.35 MB
# Dilated Inference Time: 0.0472 seconds/sample

# %%
best_model = tf.keras.models.load_model('best_unet_model.keras', 
                                       custom_objects={'combined_loss' : combined_loss,
                                                      'dice_coef' : dice_coef})
test_loss, test_dice = best_model.evaluate(X_test, y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 460ms/step - dice_coef: 0.5847 - loss: 0.3992

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.subplot(1, 2, 2)
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('Model dice_coef')
plt.ylabel('dice_coef')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.tight_layout()
plt.show()

# %%
def visualize_results(model, X, y, num_samples=3):
    predictions = model.predict(X[:num_samples])
    predictions = (predictions > 0.5).astype(np.float32)
    plt.figure(figsize=(4*num_samples, 12))
    for i in range(num_samples):
        plt.subplot(3, num_samples, i + 1)
        plt.imshow(X[i])
        plt.title('Original Image')
        plt.axis('off')
        plt.subplot(3, num_samples, i + 1 + num_samples)
        plt.imshow(y[i, :, :, 0], cmap='gray')
        plt.title(f'True Mask\nDice: {dice_coef(y[i:i+1], predictions[i:i+1]).numpy():.4f}')
        plt.axis('off')
        plt.subplot(3, num_samples, i + 1 + 2*num_samples)
        plt.imshow(predictions[i, :, :, 0], cmap='gray')
        plt.title('Predicted Mask')
        plt.axis('off')
    plt.tight_layout()
    plt.show()

visualize_results(model, X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
