# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import load_img, img_to_array 
import matplotlib.pyplot as plt
import time

# %%
def load_data(data_dir, img_size=(128, 128)):
    images = []
    masks = []

    for img_file in os.listdir(data_dir):
        if '_mask' not in img_file:
            img_path = os.path.join(data_dir, img_file)
            mask_path = os.path.join(data_dir, img_file.replace('.jpg', '_mask.jpg'))
    
            img = load_img(img_path, target_size=img_size)
            mask = load_img(mask_path, target_size=img_size, color_mode='grayscale')
    
            img = img_to_array(img) / 255.0
            mask = img_to_array(mask) / 255.0
    
            images.append(img)
            masks.append(mask)

    return np.array(images), np.array(masks)

# %%
train_dir = '/kaggle/input/testdata/split_datasets/train'
val_dir = '/kaggle/input/testdata/split_datasets/val'
test_dir = '/kaggle/input/testdata/split_datasets/test'

X_train, y_train = load_data(train_dir)
X_val, y_val = load_data(val_dir)
X_test, y_test = load_data(test_dir)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (608, 128, 128, 3)
# (608, 128, 128, 1)
# (110, 128, 128, 3)
# (110, 128, 128, 1)
# (55, 128, 128, 3)
# (55, 128, 128, 1)

# %%
plt.subplot(1, 2, 1)
plt.imshow(X_train[100], cmap='gray')
plt.subplot(1, 2, 2)
plt.imshow(y_train[100], cmap='gray')

# %%
def build_unet(input_shape=(128, 128, 3)):
    inputs = layers.Input(input_shape)

    conv1 = layers.Conv2D(32, 3, activation='relu', padding='same')(inputs)
    conv1 = layers.Conv2D(32, 3, activation='relu', padding='same')(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = layers.Conv2D(64, 3, activation='relu', padding='same')(pool1)
    conv2 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    
    conv3 = layers.Conv2D(128, 3, activation='relu', padding='same')(pool2)
    conv3 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    
    conv4 = layers.Conv2D(256, 3, activation='relu', padding='same')(pool3)
    conv4 = layers.Conv2D(256, 3, activation='relu', padding='same')(conv4)

    up7 = layers.concatenate([layers.Conv2DTranspose(128, 2, strides=(2, 2), padding='same')(conv4), conv3], axis=3)
    conv7 = layers.Conv2D(128, 3, activation='relu', padding='same')(up7)
    conv7 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv7)

    up8 = layers.concatenate([layers.Conv2DTranspose(64, 2, strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = layers.Conv2D(64, 3, activation='relu', padding='same')(up8)
    conv8 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv8)
    
    up9 = layers.concatenate([layers.Conv2DTranspose(32, 2, strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = layers.Conv2D(32, 3, activation='relu', padding='same')(up9)
    conv9 = layers.Conv2D(32, 3, activation='relu', padding='same')(conv9)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(conv9)

    model = models.Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = build_unet()
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 128, 128, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_30 (Conv2D)        │ (None, 128, 128, 32)   │            896 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_31 (Conv2D)        │ (None, 128, 128, 32)   │          9,248 │ conv2d_30[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_6           │ (None, 64, 64, 32)     │              0 │ conv2d_31[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_32 (Conv2D)        │ (None, 64, 64, 64)     │         18,496 │ max_pooling2d_6[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_33 (Conv2D)        │ (None, 64, 64, 64)     │         36,928 │ conv2d_32[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_7           │ (None, 32, 32, 64)     │              0 │ conv2d_33[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_34 (Conv2D)        │ (None, 32, 32, 128)    │         73,856 │ max_pooling2d_7[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_35 (Conv2D)        │ (None, 32, 32, 128)    │        147,584 │ conv2d_34[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_8           │ (None, 16, 16, 128)    │              0 │ conv2d_35[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_36 (Conv2D)        │ (None, 16, 16, 256)    │        295,168 │ max_pooling2d_8[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_37 (Conv2D)        │ (None, 16, 16, 256)    │        590,080 │ conv2d_36[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_6        │ (None, 32, 32, 128)    │        131,200 │ conv2d_37[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_6             │ (None, 32, 32, 256)    │              0 │ conv2d_transpose_6[0]… │
# │ (Concatenate)             │                        │                │ conv2d_35[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_38 (Conv2D)        │ (None, 32, 32, 128)    │        295,040 │ concatenate_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_39 (Conv2D)        │ (None, 32, 32, 128)    │        147,584 │ conv2d_38[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_7        │ (None, 64, 64, 64)     │         32,832 │ conv2d_39[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_7             │ (None, 64, 64, 128)    │              0 │ conv2d_transpose_7[0]… │
# │ (Concatenate)             │                        │                │ conv2d_33[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_40 (Conv2D)        │ (None, 64, 64, 64)     │         73,792 │ concatenate_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_41 (Conv2D)        │ (None, 64, 64, 64)     │         36,928 │ conv2d_40[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_8        │ (None, 128, 128, 32)   │          8,224 │ conv2d_41[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_8             │ (None, 128, 128, 64)   │              0 │ conv2d_transpose_8[0]… │
# │ (Concatenate)             │                        │                │ conv2d_31[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_42 (Conv2D)        │ (None, 128, 128, 32)   │         18,464 │ concatenate_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_43 (Conv2D)        │ (None, 128, 128, 32)   │          9,248 │ conv2d_42[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_44 (Conv2D)        │ (None, 128, 128, 1)    │             33 │ conv2d_43[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,925,601 (7.35 MB)
#  Trainable params: 1,925,601 (7.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def dice_coef(y_true, y_pred, smooth=1e-6):
    
    y_pred = tf.cast(y_pred > 0.5, dtype=tf.int32)
    y_true = tf.cast(y_true, dtype=tf.float32)
    y_pred = tf.cast(y_pred, dtype=tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred)
    intersection = tf.cast(intersection, dtype=tf.float32)

    y_true = tf.reduce_sum(y_true)
    y_pred = tf.reduce_sum(y_pred)

    result = (2.0 * (intersection) + smooth) / (y_true + y_pred + smooth)

    return result

def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

def combined_loss(y_true, y_pred, a=0.95):
    logit_loss_value = tf.keras.losses.binary_crossentropy(y_true, y_pred, from_logits=False)
    dice_loss_value = dice_loss(y_true, y_pred)

    return a * dice_loss_value + (1 - a) * logit_loss_value

# %%
model.compile(optimizer='adam',
              loss=combined_loss,
              metrics=[dice_coef])

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_dice_coef',
    factor=0.9,
    patience=3,
    min_lr=1e-6,
    mode='max',
    verbose=1
)

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_unet_model.keras',
    monitor='val_dice_coef',
    save_best_only=True,
    mode='max',
    verbose=1
)

# %%
history = model.fit(X_train, y_train,
                    batch_size=16,
                    epochs=50,
                    validation_data=(X_val, y_val),
                    callbacks=[reduce_lr, model_checkpoint]
                   )

model.save('baseline_unet_model.keras')

def measure_model_size_and_time(model, sample_input_shape):
    # 모델 사이즈 측정
    model_size = model.count_params()
    model_size_bytes = model_size * 4  # 각 파라미터가 4바이트(32비트)라고 가정

    # 계산 시간 측정
    sample_input = np.random.rand(*sample_input_shape).astype(np.float32)

    start_time = time.time()
    model.predict(sample_input)
    end_time = time.time()

    inference_time = end_time - start_time

    print(f"모델의 파라미터 수: {model_size} (약 {model_size_bytes / (1024 ** 2):.2f} MB)")
    print(f"예측 시간: {inference_time:.4f} 초")

# 사용 예시
measure_model_size_and_time(model, (1, 128, 128, 3))
# Out:
# Epoch 1/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.0064 - loss: 0.9642
# Epoch 1: val_dice_coef improved from -inf to 0.00000, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - dice_coef: 0.0061 - loss: 0.9641 - val_dice_coef: 1.1786e-10 - val_loss: 0.9586 - learning_rate: 0.0010
# Epoch 2/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 1.2671e-10 - loss: 0.9572
# Epoch 2: val_dice_coef did not improve from 0.00000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 1.2668e-10 - loss: 0.9572 - val_dice_coef: 1.1786e-10 - val_loss: 0.9570 - learning_rate: 0.0010
# Epoch 3/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 1.2710e-10 - loss: 0.9560
# Epoch 3: val_dice_coef did not improve from 0.00000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 1.2707e-10 - loss: 0.9559 - val_dice_coef: 1.1786e-10 - val_loss: 0.9549 - learning_rate: 0.0010
# Epoch 4/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 1.2531e-10 - loss: 0.9544
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
#
# Epoch 4: val_dice_coef did not improve from 0.00000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 1.2537e-10 - loss: 0.9544 - val_dice_coef: 1.1786e-10 - val_loss: 0.9542 - learning_rate: 0.0010
# Epoch 5/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.0102 - loss: 0.9441
# Epoch 5: val_dice_coef improved from 0.00000 to 0.48669, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - dice_coef: 0.0149 - loss: 0.9396 - val_dice_coef: 0.4867 - val_loss: 0.4925 - learning_rate: 9.0000e-04
# Epoch 6/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.5632 - loss: 0.4179
# Epoch 6: val_dice_coef improved from 0.48669 to 0.57521, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - dice_coef: 0.5642 - loss: 0.4170 - val_dice_coef: 0.5752 - val_loss: 0.4076 - learning_rate: 9.0000e-04
# Epoch 7/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.5653 - loss: 0.4159
# Epoch 7: val_dice_coef improved from 0.57521 to 0.59494, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - dice_coef: 0.5668 - loss: 0.4145 - val_dice_coef: 0.5949 - val_loss: 0.3890 - learning_rate: 9.0000e-04
# Epoch 8/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.6223 - loss: 0.3615
# Epoch 8: val_dice_coef improved from 0.59494 to 0.65629, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - dice_coef: 0.6227 - loss: 0.3611 - val_dice_coef: 0.6563 - val_loss: 0.3305 - learning_rate: 9.0000e-04
# Epoch 9/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.6781 - loss: 0.3081
# Epoch 9: val_dice_coef did not improve from 0.65629
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.6786 - loss: 0.3076 - val_dice_coef: 0.6386 - val_loss: 0.3472 - learning_rate: 9.0000e-04
# Epoch 10/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7267 - loss: 0.2616
# Epoch 10: val_dice_coef improved from 0.65629 to 0.69027, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - dice_coef: 0.7266 - loss: 0.2617 - val_dice_coef: 0.6903 - val_loss: 0.2975 - learning_rate: 9.0000e-04
# Epoch 11/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7372 - loss: 0.2516
# Epoch 11: val_dice_coef improved from 0.69027 to 0.69795, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - dice_coef: 0.7372 - loss: 0.2515 - val_dice_coef: 0.6979 - val_loss: 0.2903 - learning_rate: 9.0000e-04
# Epoch 12/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7434 - loss: 0.2456
# Epoch 12: val_dice_coef improved from 0.69795 to 0.72851, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - dice_coef: 0.7441 - loss: 0.2450 - val_dice_coef: 0.7285 - val_loss: 0.2611 - learning_rate: 9.0000e-04
# Epoch 13/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7754 - loss: 0.2150
# Epoch 13: val_dice_coef improved from 0.72851 to 0.73105, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - dice_coef: 0.7751 - loss: 0.2152 - val_dice_coef: 0.7310 - val_loss: 0.2585 - learning_rate: 9.0000e-04
# Epoch 14/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7886 - loss: 0.2024
# Epoch 14: val_dice_coef did not improve from 0.73105
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.7882 - loss: 0.2028 - val_dice_coef: 0.6350 - val_loss: 0.3513 - learning_rate: 9.0000e-04
# Epoch 15/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.7834 - loss: 0.2073
# Epoch 15: val_dice_coef did not improve from 0.73105
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.7834 - loss: 0.2074 - val_dice_coef: 0.7299 - val_loss: 0.2599 - learning_rate: 9.0000e-04
# Epoch 16/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.7957 - loss: 0.1956
# Epoch 16: val_dice_coef improved from 0.73105 to 0.73873, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - dice_coef: 0.7957 - loss: 0.1956 - val_dice_coef: 0.7387 - val_loss: 0.2516 - learning_rate: 9.0000e-04
# Epoch 17/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8187 - loss: 0.1734
# Epoch 17: val_dice_coef improved from 0.73873 to 0.74431, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - dice_coef: 0.8183 - loss: 0.1739 - val_dice_coef: 0.7443 - val_loss: 0.2462 - learning_rate: 9.0000e-04
# Epoch 18/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8150 - loss: 0.1771
# Epoch 18: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8148 - loss: 0.1773 - val_dice_coef: 0.7129 - val_loss: 0.2766 - learning_rate: 9.0000e-04
# Epoch 19/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8123 - loss: 0.1796
# Epoch 19: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8124 - loss: 0.1796 - val_dice_coef: 0.6999 - val_loss: 0.2888 - learning_rate: 9.0000e-04
# Epoch 20/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8227 - loss: 0.1697
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
#
# Epoch 20: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8226 - loss: 0.1697 - val_dice_coef: 0.7257 - val_loss: 0.2641 - learning_rate: 9.0000e-04
# Epoch 21/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8426 - loss: 0.1507
# Epoch 21: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8424 - loss: 0.1509 - val_dice_coef: 0.7321 - val_loss: 0.2585 - learning_rate: 8.1000e-04
# Epoch 22/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8436 - loss: 0.1497
# Epoch 22: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8435 - loss: 0.1498 - val_dice_coef: 0.6980 - val_loss: 0.2915 - learning_rate: 8.1000e-04
# Epoch 23/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8518 - loss: 0.1419
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0007290000503417104.
#
# Epoch 23: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8516 - loss: 0.1420 - val_dice_coef: 0.7284 - val_loss: 0.2619 - learning_rate: 8.1000e-04
# Epoch 24/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8598 - loss: 0.1341
# Epoch 24: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8597 - loss: 0.1343 - val_dice_coef: 0.7085 - val_loss: 0.2811 - learning_rate: 7.2900e-04
# Epoch 25/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8672 - loss: 0.1271
# Epoch 25: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8669 - loss: 0.1273 - val_dice_coef: 0.6990 - val_loss: 0.2903 - learning_rate: 7.2900e-04
# Epoch 26/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8629 - loss: 0.1312
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0006561000715009868.
#
# Epoch 26: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8628 - loss: 0.1313 - val_dice_coef: 0.6554 - val_loss: 0.3324 - learning_rate: 7.2900e-04
# Epoch 27/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8598 - loss: 0.1342
# Epoch 27: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8599 - loss: 0.1340 - val_dice_coef: 0.7278 - val_loss: 0.2629 - learning_rate: 6.5610e-04
# Epoch 28/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8578 - loss: 0.1361
# Epoch 28: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8577 - loss: 0.1362 - val_dice_coef: 0.7077 - val_loss: 0.2822 - learning_rate: 6.5610e-04
# Epoch 29/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8632 - loss: 0.1310
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005904900433961303.
#
# Epoch 29: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8635 - loss: 0.1307 - val_dice_coef: 0.7222 - val_loss: 0.2679 - learning_rate: 6.5610e-04
# Epoch 30/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8820 - loss: 0.1129
# Epoch 30: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8818 - loss: 0.1131 - val_dice_coef: 0.6808 - val_loss: 0.3080 - learning_rate: 5.9049e-04
# Epoch 31/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8859 - loss: 0.1092
# Epoch 31: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8857 - loss: 0.1094 - val_dice_coef: 0.6965 - val_loss: 0.2935 - learning_rate: 5.9049e-04
# Epoch 32/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8895 - loss: 0.1057
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005314410547725857.
#
# Epoch 32: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8895 - loss: 0.1057 - val_dice_coef: 0.7193 - val_loss: 0.2708 - learning_rate: 5.9049e-04
# Epoch 33/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8898 - loss: 0.1055
# Epoch 33: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8899 - loss: 0.1054 - val_dice_coef: 0.7037 - val_loss: 0.2863 - learning_rate: 5.3144e-04
# Epoch 34/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8991 - loss: 0.0965
# Epoch 34: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8990 - loss: 0.0966 - val_dice_coef: 0.6992 - val_loss: 0.2911 - learning_rate: 5.3144e-04
# Epoch 35/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.8983 - loss: 0.0973
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.00047829695977270604.
#
# Epoch 35: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8983 - loss: 0.0973 - val_dice_coef: 0.7338 - val_loss: 0.2571 - learning_rate: 5.3144e-04
# Epoch 36/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.9073 - loss: 0.0887
# Epoch 36: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.9071 - loss: 0.0889 - val_dice_coef: 0.6734 - val_loss: 0.3165 - learning_rate: 4.7830e-04
# Epoch 37/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9069 - loss: 0.0891
# Epoch 37: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.9068 - loss: 0.0892 - val_dice_coef: 0.7110 - val_loss: 0.2797 - learning_rate: 4.7830e-04
# Epoch 38/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.9142 - loss: 0.0821
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0004304672533180565.
#
# Epoch 38: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.9139 - loss: 0.0824 - val_dice_coef: 0.6845 - val_loss: 0.3057 - learning_rate: 4.7830e-04
# Epoch 39/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.9149 - loss: 0.0814
# Epoch 39: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.9148 - loss: 0.0816 - val_dice_coef: 0.7191 - val_loss: 0.2714 - learning_rate: 4.3047e-04
# Epoch 40/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.9075 - loss: 0.0885
# Epoch 40: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.9077 - loss: 0.0884 - val_dice_coef: 0.7004 - val_loss: 0.2905 - learning_rate: 4.3047e-04
# Epoch 41/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.9177 - loss: 0.0787
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.00038742052274756136.
#
# Epoch 41: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.9177 - loss: 0.0788 - val_dice_coef: 0.6730 - val_loss: 0.3173 - learning_rate: 4.3047e-04
# Epoch 42/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9220 - loss: 0.0746
# Epoch 42: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.9219 - loss: 0.0747 - val_dice_coef: 0.6755 - val_loss: 0.3150 - learning_rate: 3.8742e-04
# Epoch 43/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9240 - loss: 0.0728
# Epoch 43: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.9238 - loss: 0.0729 - val_dice_coef: 0.6972 - val_loss: 0.2942 - learning_rate: 3.8742e-04
# Epoch 44/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.9222 - loss: 0.0744
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0003486784757114947.
#
# Epoch 44: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.9222 - loss: 0.0745 - val_dice_coef: 0.6976 - val_loss: 0.2932 - learning_rate: 3.8742e-04
# Epoch 45/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.9205 - loss: 0.0761
# Epoch 45: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.9206 - loss: 0.0760 - val_dice_coef: 0.6861 - val_loss: 0.3040 - learning_rate: 3.4868e-04
# Epoch 46/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.9272 - loss: 0.0697
# Epoch 46: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.9271 - loss: 0.0697 - val_dice_coef: 0.7049 - val_loss: 0.2868 - learning_rate: 3.4868e-04
# Epoch 47/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.9316 - loss: 0.0655
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.00031381062290165574.
#
# Epoch 47: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.9314 - loss: 0.0657 - val_dice_coef: 0.7127 - val_loss: 0.2792 - learning_rate: 3.4868e-04
# Epoch 48/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.9329 - loss: 0.0643
# Epoch 48: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.9327 - loss: 0.0644 - val_dice_coef: 0.7023 - val_loss: 0.2896 - learning_rate: 3.1381e-04
# Epoch 49/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.9325 - loss: 0.0646
# Epoch 49: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.9325 - loss: 0.0646 - val_dice_coef: 0.6986 - val_loss: 0.2937 - learning_rate: 3.1381e-04
# Epoch 50/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dice_coef: 0.9358 - loss: 0.0615
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0002824295632308349.
#
# Epoch 50: val_dice_coef did not improve from 0.74431
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.9357 - loss: 0.0615 - val_dice_coef: 0.6948 - val_loss: 0.2976 - learning_rate: 3.1381e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step
# 모델의 파라미터 수: 1925601 (약 7.35 MB)
# 예측 시간: 0.3888 초

# %%
best_model = tf.keras.models.load_model('best_unet_model.keras', 
                                        custom_objects={'combined_loss': combined_loss,
                                                        'dice_coef': dice_coef})

test_loss, test_dice = best_model.evaluate(X_test, y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 421ms/step - dice_coef: 0.5128 - loss: 0.4663

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.subplot(1, 2, 2)
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('Model dice_coef')
plt.ylabel('dice_coef')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.tight_layout()
plt.show()

# %%
def visualize_results(model, X, y, num_samples=3):
    predictions = model.predict(X[:num_samples])
    predictions = (predictions > 0.5).astype(np.float32)
    plt.figure(figsize=(4*num_samples, 12))
    for i in range(num_samples):
        plt.subplot(3, num_samples, i + 1)
        plt.imshow(X[i])
        plt.title('Original Image')
        plt.axis('off')
        plt.subplot(3, num_samples, i + 1 + num_samples)
        plt.imshow(y[i, :, :, 0], cmap='gray')
        plt.title(f'True Mask\nDice: {dice_coef(y[i:i+1], predictions[i:i+1]).numpy():.4f}')
        plt.axis('off')
        plt.subplot(3, num_samples, i + 1 + 2*num_samples)
        plt.imshow(predictions[i, :, :, 0], cmap='gray')
        plt.title('Predicted Mask')
        plt.axis('off')
    plt.tight_layout()
    plt.show()

visualize_results(model, X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
