# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import load_img, img_to_array 
import matplotlib.pyplot as plt
import time

# %%
def load_data(data_dir, img_size=(128, 128)):
    images = []
    masks = []

    for img_file in os.listdir(data_dir):
        if '_mask' not in img_file:
            img_path = os.path.join(data_dir, img_file)
            mask_path = os.path.join(data_dir, img_file.replace('.jpg', '_mask.jpg'))
    
            img = load_img(img_path, target_size=img_size)
            mask = load_img(mask_path, target_size=img_size, color_mode='grayscale')
    
            img = img_to_array(img) / 255.0
            mask = img_to_array(mask) / 255.0
    
            images.append(img)
            masks.append(mask)

    return np.array(images), np.array(masks)

# %%
train_dir = '/kaggle/input/unet1234/split_datasets/train'
val_dir = '/kaggle/input/unet1234/split_datasets/val'
test_dir = '/kaggle/input/unet1234/split_datasets/test'

X_train, y_train = load_data(train_dir)
X_val, y_val = load_data(val_dir)
X_test, y_test = load_data(test_dir)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (608, 128, 128, 3)
# (608, 128, 128, 1)
# (110, 128, 128, 3)
# (110, 128, 128, 1)
# (55, 128, 128, 3)
# (55, 128, 128, 1)

# %%
def build_unet(input_shape=(128, 128, 3)):
    inputs = layers.Input(input_shape)

    conv1 = layers.Conv2D(32, 3, activation='relu', padding='same')(inputs)
    conv1 = layers.Conv2D(32, 3, activation='relu', padding='same')(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = layers.Conv2D(64, 3, activation='relu', padding='same')(pool1)
    conv2 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    
    conv3 = layers.Conv2D(128, 3, activation='relu', padding='same')(pool2)
    conv3 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    
    conv4 = layers.Conv2D(256, 3, activation='relu', padding='same')(pool3)
    conv4 = layers.Conv2D(256, 3, activation='relu', padding='same')(conv4)

    up7 = layers.concatenate([layers.Conv2DTranspose(128, 2, strides=(2, 2), padding='same')(conv4), conv3], axis=3)
    conv7 = layers.Conv2D(128, 3, activation='relu', padding='same')(up7)
    conv7 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv7)

    up8 = layers.concatenate([layers.Conv2DTranspose(64, 2, strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = layers.Conv2D(64, 3, activation='relu', padding='same')(up8)
    conv8 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv8)
    
    up9 = layers.concatenate([layers.Conv2DTranspose(32, 2, strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = layers.Conv2D(32, 3, activation='relu', padding='same')(up9)
    conv9 = layers.Conv2D(32, 3, activation='relu', padding='same')(conv9)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(conv9)

    model = models.Model(inputs=inputs, outputs=outputs)
    
    return model

# %%
model = build_unet()
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5             │ (None, 128, 128, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_75 (Conv2D)        │ (None, 128, 128, 32)   │            896 │ input_layer_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_76 (Conv2D)        │ (None, 128, 128, 32)   │          9,248 │ conv2d_75[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_15          │ (None, 64, 64, 32)     │              0 │ conv2d_76[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_77 (Conv2D)        │ (None, 64, 64, 64)     │         18,496 │ max_pooling2d_15[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_78 (Conv2D)        │ (None, 64, 64, 64)     │         36,928 │ conv2d_77[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_16          │ (None, 32, 32, 64)     │              0 │ conv2d_78[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_79 (Conv2D)        │ (None, 32, 32, 128)    │         73,856 │ max_pooling2d_16[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_80 (Conv2D)        │ (None, 32, 32, 128)    │        147,584 │ conv2d_79[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_17          │ (None, 16, 16, 128)    │              0 │ conv2d_80[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_81 (Conv2D)        │ (None, 16, 16, 256)    │        295,168 │ max_pooling2d_17[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_82 (Conv2D)        │ (None, 16, 16, 256)    │        590,080 │ conv2d_81[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_15       │ (None, 32, 32, 128)    │        131,200 │ conv2d_82[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_15            │ (None, 32, 32, 256)    │              0 │ conv2d_transpose_15[0… │
# │ (Concatenate)             │                        │                │ conv2d_80[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_83 (Conv2D)        │ (None, 32, 32, 128)    │        295,040 │ concatenate_15[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_84 (Conv2D)        │ (None, 32, 32, 128)    │        147,584 │ conv2d_83[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_16       │ (None, 64, 64, 64)     │         32,832 │ conv2d_84[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_16            │ (None, 64, 64, 128)    │              0 │ conv2d_transpose_16[0… │
# │ (Concatenate)             │                        │                │ conv2d_78[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_85 (Conv2D)        │ (None, 64, 64, 64)     │         73,792 │ concatenate_16[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_86 (Conv2D)        │ (None, 64, 64, 64)     │         36,928 │ conv2d_85[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_17       │ (None, 128, 128, 32)   │          8,224 │ conv2d_86[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_17            │ (None, 128, 128, 64)   │              0 │ conv2d_transpose_17[0… │
# │ (Concatenate)             │                        │                │ conv2d_76[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_87 (Conv2D)        │ (None, 128, 128, 32)   │         18,464 │ concatenate_17[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_88 (Conv2D)        │ (None, 128, 128, 32)   │          9,248 │ conv2d_87[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_89 (Conv2D)        │ (None, 128, 128, 1)    │             33 │ conv2d_88[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,925,601 (7.35 MB)
#  Trainable params: 1,925,601 (7.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_pred = tf.cast(y_pred > 0.5, dtype=tf.int32)
    y_true = tf.cast(y_true, dtype=tf.float32)
    y_pred = tf.cast(y_pred, dtype=tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred)
    intersection = tf.cast(intersection, dtype=tf.float32)

    y_true = tf.reduce_sum(y_true)
    y_pred = tf.reduce_sum(y_pred)

    result = (2.0 * (intersection) + smooth) / (y_true + y_pred + smooth)

    return result

def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

def combined_loss(y_true, y_pred, a=0.95):
    logit_loss_value = tf.keras.losses.binary_crossentropy(y_true, y_pred, from_logits=False)
    dice_loss_value = dice_loss(y_true, y_pred)

    return a * dice_loss_value + (1 - a) * logit_loss_value

# %%
model.compile(optimizer='adam',
              loss=combined_loss,
              metrics=[dice_coef])

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_dice_coef',
    factor=0.9,
    patience=3,
    min_lr=1e-6,
    mode='max',
    verbose=1
)

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_unet_model.keras',
    monitor='val_dice_coef',
    save_best_only=True,
    mode='max',
    verbose=1
)

# %%
history = model.fit(X_train, y_train,
                    batch_size=16,
                    epochs=50,
                    validation_data=(X_val, y_val),
                    callbacks=[reduce_lr, model_checkpoint]
                   )

model.save('baseline_unet_model.keras')

def measure_model_size_and_time(model, sample_input_shape):
    # 모델 사이즈 측정
    model_size = model.count_params()
    model_size_bytes = model_size * 4  # 각 파라미터가 4바이트(32비트)라고 가정

    # 계산 시간 측정
    sample_input = np.random.rand(*sample_input_shape).astype(np.float32)

    start_time = time.time()
    model.predict(sample_input)
    end_time = time.time()

    inference_time = end_time - start_time

    print(f"모델의 파라미터 수: {model_size} (약 {model_size_bytes / (1024 ** 2):.2f} MB)")
    print(f"예측 시간: {inference_time:.4f} 초")

# 사용 예시
measure_model_size_and_time(model, (1, 128, 128, 3))
# Out:
# Epoch 1/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.0072 - loss: 0.9627
# Epoch 1: val_dice_coef improved from -inf to 0.00000, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - dice_coef: 0.0069 - loss: 0.9627 - val_dice_coef: 1.1786e-10 - val_loss: 0.9586 - learning_rate: 0.0010
# Epoch 2/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 1.2648e-10 - loss: 0.9572
# Epoch 2: val_dice_coef did not improve from 0.00000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 1.2647e-10 - loss: 0.9572 - val_dice_coef: 1.1786e-10 - val_loss: 0.9559 - learning_rate: 0.0010
# Epoch 3/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 1.2639e-10 - loss: 0.9561
# Epoch 3: val_dice_coef did not improve from 0.00000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 1.2637e-10 - loss: 0.9561 - val_dice_coef: 1.1786e-10 - val_loss: 0.9548 - learning_rate: 0.0010
# Epoch 4/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.1405 - loss: 0.8206
# Epoch 4: val_dice_coef improved from 0.00000 to 0.61032, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - dice_coef: 0.1490 - loss: 0.8126 - val_dice_coef: 0.6103 - val_loss: 0.3748 - learning_rate: 0.0010
# Epoch 5/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.5515 - loss: 0.4291
# Epoch 5: val_dice_coef improved from 0.61032 to 0.62544, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - dice_coef: 0.5529 - loss: 0.4277 - val_dice_coef: 0.6254 - val_loss: 0.3602 - learning_rate: 0.0010
# Epoch 6/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.5970 - loss: 0.3856
# Epoch 6: val_dice_coef improved from 0.62544 to 0.66152, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - dice_coef: 0.5976 - loss: 0.3850 - val_dice_coef: 0.6615 - val_loss: 0.3257 - learning_rate: 0.0010
# Epoch 7/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.6574 - loss: 0.3279
# Epoch 7: val_dice_coef did not improve from 0.66152
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.6576 - loss: 0.3276 - val_dice_coef: 0.6580 - val_loss: 0.3294 - learning_rate: 0.0010
# Epoch 8/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.6844 - loss: 0.3020
# Epoch 8: val_dice_coef did not improve from 0.66152
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.6846 - loss: 0.3017 - val_dice_coef: 0.6415 - val_loss: 0.3453 - learning_rate: 0.0010
# Epoch 9/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.7134 - loss: 0.2743
# Epoch 9: val_dice_coef improved from 0.66152 to 0.68646, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - dice_coef: 0.7140 - loss: 0.2737 - val_dice_coef: 0.6865 - val_loss: 0.3024 - learning_rate: 0.0010
# Epoch 10/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.7429 - loss: 0.2460
# Epoch 10: val_dice_coef improved from 0.68646 to 0.70527, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - dice_coef: 0.7431 - loss: 0.2459 - val_dice_coef: 0.7053 - val_loss: 0.2843 - learning_rate: 0.0010
# Epoch 11/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.7598 - loss: 0.2299
# Epoch 11: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.7595 - loss: 0.2301 - val_dice_coef: 0.6567 - val_loss: 0.3310 - learning_rate: 0.0010
# Epoch 12/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.7611 - loss: 0.2287
# Epoch 12: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.7610 - loss: 0.2288 - val_dice_coef: 0.6593 - val_loss: 0.3284 - learning_rate: 0.0010
# Epoch 13/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.7486 - loss: 0.2406
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
#
# Epoch 13: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.7493 - loss: 0.2400 - val_dice_coef: 0.6721 - val_loss: 0.3158 - learning_rate: 0.0010
# Epoch 14/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.7884 - loss: 0.2026
# Epoch 14: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.7884 - loss: 0.2025 - val_dice_coef: 0.6619 - val_loss: 0.3258 - learning_rate: 9.0000e-04
# Epoch 15/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8078 - loss: 0.1839
# Epoch 15: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8075 - loss: 0.1843 - val_dice_coef: 0.6577 - val_loss: 0.3295 - learning_rate: 9.0000e-04
# Epoch 16/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8135 - loss: 0.1785
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
#
# Epoch 16: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8133 - loss: 0.1787 - val_dice_coef: 0.6473 - val_loss: 0.3397 - learning_rate: 9.0000e-04
# Epoch 17/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8231 - loss: 0.1693
# Epoch 17: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8228 - loss: 0.1696 - val_dice_coef: 0.6978 - val_loss: 0.2909 - learning_rate: 8.1000e-04
# Epoch 18/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8261 - loss: 0.1665
# Epoch 18: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8258 - loss: 0.1667 - val_dice_coef: 0.6325 - val_loss: 0.3544 - learning_rate: 8.1000e-04
# Epoch 19/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8331 - loss: 0.1598
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0007290000503417104.
#
# Epoch 19: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8331 - loss: 0.1598 - val_dice_coef: 0.6711 - val_loss: 0.3167 - learning_rate: 8.1000e-04
# Epoch 20/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8395 - loss: 0.1536
# Epoch 20: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8395 - loss: 0.1536 - val_dice_coef: 0.6400 - val_loss: 0.3473 - learning_rate: 7.2900e-04
# Epoch 21/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8371 - loss: 0.1558
# Epoch 21: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8373 - loss: 0.1557 - val_dice_coef: 0.6263 - val_loss: 0.3603 - learning_rate: 7.2900e-04
# Epoch 22/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8459 - loss: 0.1475
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0006561000715009868.
#
# Epoch 22: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8457 - loss: 0.1476 - val_dice_coef: 0.6913 - val_loss: 0.2976 - learning_rate: 7.2900e-04
# Epoch 23/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8476 - loss: 0.1458
# Epoch 23: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8477 - loss: 0.1458 - val_dice_coef: 0.6567 - val_loss: 0.3313 - learning_rate: 6.5610e-04
# Epoch 24/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8631 - loss: 0.1310
# Epoch 24: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8629 - loss: 0.1312 - val_dice_coef: 0.6375 - val_loss: 0.3500 - learning_rate: 6.5610e-04
# Epoch 25/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8640 - loss: 0.1301
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005904900433961303.
#
# Epoch 25: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8640 - loss: 0.1301 - val_dice_coef: 0.6623 - val_loss: 0.3265 - learning_rate: 6.5610e-04
# Epoch 26/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8723 - loss: 0.1222
# Epoch 26: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.8722 - loss: 0.1223 - val_dice_coef: 0.6677 - val_loss: 0.3209 - learning_rate: 5.9049e-04
# Epoch 27/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8721 - loss: 0.1224
# Epoch 27: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8721 - loss: 0.1224 - val_dice_coef: 0.7001 - val_loss: 0.2895 - learning_rate: 5.9049e-04
# Epoch 28/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8732 - loss: 0.1213
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005314410547725857.
#
# Epoch 28: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8732 - loss: 0.1213 - val_dice_coef: 0.6905 - val_loss: 0.2990 - learning_rate: 5.9049e-04
# Epoch 29/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8815 - loss: 0.1134
# Epoch 29: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8815 - loss: 0.1134 - val_dice_coef: 0.6542 - val_loss: 0.3346 - learning_rate: 5.3144e-04
# Epoch 30/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8887 - loss: 0.1065
# Epoch 30: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8886 - loss: 0.1066 - val_dice_coef: 0.6730 - val_loss: 0.3159 - learning_rate: 5.3144e-04
# Epoch 31/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8906 - loss: 0.1047
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.00047829695977270604.
#
# Epoch 31: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8905 - loss: 0.1048 - val_dice_coef: 0.6677 - val_loss: 0.3225 - learning_rate: 5.3144e-04
# Epoch 32/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.8963 - loss: 0.0993
# Epoch 32: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.8962 - loss: 0.0993 - val_dice_coef: 0.6723 - val_loss: 0.3173 - learning_rate: 4.7830e-04
# Epoch 33/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9022 - loss: 0.0936
# Epoch 33: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9020 - loss: 0.0938 - val_dice_coef: 0.6390 - val_loss: 0.3496 - learning_rate: 4.7830e-04
# Epoch 34/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9015 - loss: 0.0942
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0004304672533180565.
#
# Epoch 34: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9013 - loss: 0.0944 - val_dice_coef: 0.6772 - val_loss: 0.3121 - learning_rate: 4.7830e-04
# Epoch 35/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dice_coef: 0.9039 - loss: 0.0920
# Epoch 35: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9037 - loss: 0.0921 - val_dice_coef: 0.6653 - val_loss: 0.3243 - learning_rate: 4.3047e-04
# Epoch 36/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9083 - loss: 0.0878
# Epoch 36: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9081 - loss: 0.0880 - val_dice_coef: 0.6582 - val_loss: 0.3311 - learning_rate: 4.3047e-04
# Epoch 37/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9074 - loss: 0.0886
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00038742052274756136.
#
# Epoch 37: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9075 - loss: 0.0885 - val_dice_coef: 0.6568 - val_loss: 0.3331 - learning_rate: 4.3047e-04
# Epoch 38/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9138 - loss: 0.0824
# Epoch 38: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9136 - loss: 0.0827 - val_dice_coef: 0.6567 - val_loss: 0.3328 - learning_rate: 3.8742e-04
# Epoch 39/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9130 - loss: 0.0832
# Epoch 39: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9129 - loss: 0.0833 - val_dice_coef: 0.6709 - val_loss: 0.3196 - learning_rate: 3.8742e-04
# Epoch 40/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9155 - loss: 0.0809
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0003486784757114947.
#
# Epoch 40: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9154 - loss: 0.0810 - val_dice_coef: 0.6573 - val_loss: 0.3331 - learning_rate: 3.8742e-04
# Epoch 41/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9193 - loss: 0.0772
# Epoch 41: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9193 - loss: 0.0772 - val_dice_coef: 0.6498 - val_loss: 0.3405 - learning_rate: 3.4868e-04
# Epoch 42/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9257 - loss: 0.0711
# Epoch 42: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9254 - loss: 0.0714 - val_dice_coef: 0.6918 - val_loss: 0.2997 - learning_rate: 3.4868e-04
# Epoch 43/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9223 - loss: 0.0744
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.00031381062290165574.
#
# Epoch 43: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9222 - loss: 0.0744 - val_dice_coef: 0.6758 - val_loss: 0.3159 - learning_rate: 3.4868e-04
# Epoch 44/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9252 - loss: 0.0716
# Epoch 44: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9252 - loss: 0.0716 - val_dice_coef: 0.6682 - val_loss: 0.3235 - learning_rate: 3.1381e-04
# Epoch 45/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9285 - loss: 0.0684
# Epoch 45: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9285 - loss: 0.0685 - val_dice_coef: 0.6368 - val_loss: 0.3545 - learning_rate: 3.1381e-04
# Epoch 46/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9287 - loss: 0.0682
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0002824295632308349.
#
# Epoch 46: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9286 - loss: 0.0684 - val_dice_coef: 0.6816 - val_loss: 0.3107 - learning_rate: 3.1381e-04
# Epoch 47/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9288 - loss: 0.0681
# Epoch 47: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9287 - loss: 0.0682 - val_dice_coef: 0.6722 - val_loss: 0.3196 - learning_rate: 2.8243e-04
# Epoch 48/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9250 - loss: 0.0717
# Epoch 48: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9253 - loss: 0.0715 - val_dice_coef: 0.6513 - val_loss: 0.3412 - learning_rate: 2.8243e-04
# Epoch 49/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9390 - loss: 0.0583
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.00025418660952709616.
#
# Epoch 49: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9387 - loss: 0.0586 - val_dice_coef: 0.6697 - val_loss: 0.3228 - learning_rate: 2.8243e-04
# Epoch 50/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dice_coef: 0.9371 - loss: 0.0602
# Epoch 50: val_dice_coef did not improve from 0.70527
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - dice_coef: 0.9369 - loss: 0.0604 - val_dice_coef: 0.6251 - val_loss: 0.3675 - learning_rate: 2.5419e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 모델의 파라미터 수: 1925601 (약 7.35 MB)
# 예측 시간: 0.4445 초

# %%
best_model = tf.keras.models.load_model('best_unet_model.keras', 
                                        custom_objects={'combined_loss': combined_loss,
                                                        'dice_coef': dice_coef})

test_loss, test_dice = best_model.evaluate(X_test, y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 482ms/step - dice_coef: 0.5021 - loss: 0.4772

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.subplot(1, 2, 2)
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('Model dice_coef')
plt.ylabel('dice_coef')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.tight_layout()
plt.show()

# %%
def visualize_results(model, X, y, num_samples=3):
    predictions = model.predict(X[:num_samples])
    predictions = (predictions > 0.5).astype(np.float32)
    plt.figure(figsize=(4*num_samples, 12))
    for i in range(num_samples):
        plt.subplot(3, num_samples, i + 1)
        plt.imshow(X[i])
        plt.title('Original Image')
        plt.axis('off')
        plt.subplot(3, num_samples, i + 1 + num_samples)
        plt.imshow(y[i, :, :, 0], cmap='gray')
        plt.title(f'True Mask\nDice: {dice_coef(y[i:i+1], predictions[i:i+1]).numpy():.4f}')
        plt.axis('off')
        plt.subplot(3, num_samples, i + 1 + 2*num_samples)
        plt.imshow(predictions[i, :, :, 0], cmap='gray')
        plt.title('Predicted Mask')
        plt.axis('off')
    plt.tight_layout()
    plt.show()

visualize_results(model, X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
