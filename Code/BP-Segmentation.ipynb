# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import load_img, img_to_array 
import matplotlib.pyplot as plt
import time

# %%
def load_data(data_dir, img_size=(128, 128)):
    images = []
    masks = []

    for img_file in os.listdir(data_dir):
        if '_mask' not in img_file:
            img_path = os.path.join(data_dir, img_file)
            mask_path = os.path.join(data_dir, img_file.replace('.jpg', '_mask.jpg'))
    
            img = load_img(img_path, target_size=img_size)
            mask = load_img(mask_path, target_size=img_size, color_mode='grayscale')
    
            img = img_to_array(img) / 255.0
            mask = img_to_array(mask) / 255.0
    
            images.append(img)
            masks.append(mask)

    return np.array(images), np.array(masks)

# %%
train_dir = '/kaggle/input/unet1234/split_datasets/train'
val_dir = '/kaggle/input/unet1234/split_datasets/val'
test_dir = '/kaggle/input/unet1234/split_datasets/test'

X_train, y_train = load_data(train_dir)
X_val, y_val = load_data(val_dir)
X_test, y_test = load_data(test_dir)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (608, 128, 128, 3)
# (608, 128, 128, 1)
# (110, 128, 128, 3)
# (110, 128, 128, 1)
# (55, 128, 128, 3)
# (55, 128, 128, 1)

# %%
def build_unet(input_shape=(128, 128, 3)):
    inputs = layers.Input(input_shape)

    conv1 = layers.Conv2D(32, 3, activation='relu', padding='same')(inputs)
    conv1 = layers.Conv2D(32, 3, activation='relu', padding='same')(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = layers.Conv2D(64, 3, activation='relu', padding='same')(pool1)
    conv2 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    
    conv3 = layers.Conv2D(128, 3, activation='relu', padding='same')(pool2)
    conv3 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    
    conv4 = layers.Conv2D(256, 3, activation='relu', padding='same')(pool3)
    conv4 = layers.Conv2D(256, 3, activation='relu', padding='same')(conv4)

    up7 = layers.concatenate([layers.Conv2DTranspose(128, 2, strides=(2, 2), padding='same')(conv4), conv3], axis=3)
    conv7 = layers.Conv2D(128, 3, activation='relu', padding='same')(up7)
    conv7 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv7)

    up8 = layers.concatenate([layers.Conv2DTranspose(64, 2, strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = layers.Conv2D(64, 3, activation='relu', padding='same')(up8)
    conv8 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv8)
    
    up9 = layers.concatenate([layers.Conv2DTranspose(32, 2, strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = layers.Conv2D(32, 3, activation='relu', padding='same')(up9)
    conv9 = layers.Conv2D(32, 3, activation='relu', padding='same')(conv9)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(conv9)

    model = models.Model(inputs=inputs, outputs=outputs)
    
    return model

# %%
model = build_unet()
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3             │ (None, 128, 128, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_45 (Conv2D)        │ (None, 128, 128, 32)   │            896 │ input_layer_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_46 (Conv2D)        │ (None, 128, 128, 32)   │          9,248 │ conv2d_45[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_9           │ (None, 64, 64, 32)     │              0 │ conv2d_46[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_47 (Conv2D)        │ (None, 64, 64, 64)     │         18,496 │ max_pooling2d_9[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_48 (Conv2D)        │ (None, 64, 64, 64)     │         36,928 │ conv2d_47[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_10          │ (None, 32, 32, 64)     │              0 │ conv2d_48[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_49 (Conv2D)        │ (None, 32, 32, 128)    │         73,856 │ max_pooling2d_10[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_50 (Conv2D)        │ (None, 32, 32, 128)    │        147,584 │ conv2d_49[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_11          │ (None, 16, 16, 128)    │              0 │ conv2d_50[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_51 (Conv2D)        │ (None, 16, 16, 256)    │        295,168 │ max_pooling2d_11[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_52 (Conv2D)        │ (None, 16, 16, 256)    │        590,080 │ conv2d_51[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_9        │ (None, 32, 32, 128)    │        131,200 │ conv2d_52[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_9             │ (None, 32, 32, 256)    │              0 │ conv2d_transpose_9[0]… │
# │ (Concatenate)             │                        │                │ conv2d_50[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_53 (Conv2D)        │ (None, 32, 32, 128)    │        295,040 │ concatenate_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_54 (Conv2D)        │ (None, 32, 32, 128)    │        147,584 │ conv2d_53[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_10       │ (None, 64, 64, 64)     │         32,832 │ conv2d_54[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_10            │ (None, 64, 64, 128)    │              0 │ conv2d_transpose_10[0… │
# │ (Concatenate)             │                        │                │ conv2d_48[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_55 (Conv2D)        │ (None, 64, 64, 64)     │         73,792 │ concatenate_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_56 (Conv2D)        │ (None, 64, 64, 64)     │         36,928 │ conv2d_55[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_11       │ (None, 128, 128, 32)   │          8,224 │ conv2d_56[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_11            │ (None, 128, 128, 64)   │              0 │ conv2d_transpose_11[0… │
# │ (Concatenate)             │                        │                │ conv2d_46[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_57 (Conv2D)        │ (None, 128, 128, 32)   │         18,464 │ concatenate_11[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_58 (Conv2D)        │ (None, 128, 128, 32)   │          9,248 │ conv2d_57[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_59 (Conv2D)        │ (None, 128, 128, 1)    │             33 │ conv2d_58[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,925,601 (7.35 MB)
#  Trainable params: 1,925,601 (7.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_pred = tf.cast(y_pred > 0.5, dtype=tf.int32)
    y_true = tf.cast(y_true, dtype=tf.float32)
    y_pred = tf.cast(y_pred, dtype=tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred)
    intersection = tf.cast(intersection, dtype=tf.float32)

    y_true = tf.reduce_sum(y_true)
    y_pred = tf.reduce_sum(y_pred)

    result = (2.0 * (intersection) + smooth) / (y_true + y_pred + smooth)

    return result

def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

def combined_loss(y_true, y_pred, a=0.95):
    logit_loss_value = tf.keras.losses.binary_crossentropy(y_true, y_pred, from_logits=False)
    dice_loss_value = dice_loss(y_true, y_pred)

    return a * dice_loss_value + (1 - a) * logit_loss_value

# %%
model.compile(optimizer='adam',
              loss=combined_loss,
              metrics=[dice_coef])

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_dice_coef',
    factor=0.9,
    patience=3,
    min_lr=1e-6,
    mode='max',
    verbose=1
)

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_unet_model.keras',
    monitor='val_dice_coef',
    save_best_only=True,
    mode='max',
    verbose=1
)

# %%
history = model.fit(X_train, y_train,
                    batch_size=16,
                    epochs=50,
                    validation_data=(X_val, y_val),
                    callbacks=[reduce_lr, model_checkpoint]
                   )

model.save('baseline_unet_model.keras')

def measure_model_size_and_time(model, sample_input_shape):
    # 모델 사이즈 측정
    model_size = model.count_params()
    model_size_bytes = model_size * 4  # 각 파라미터가 4바이트(32비트)라고 가정

    # 계산 시간 측정
    sample_input = np.random.rand(*sample_input_shape).astype(np.float32)

    start_time = time.time()
    model.predict(sample_input)
    end_time = time.time()

    inference_time = end_time - start_time

    print(f"모델의 파라미터 수: {model_size} (약 {model_size_bytes / (1024 ** 2):.2f} MB)")
    print(f"예측 시간: {inference_time:.4f} 초")

# 사용 예시
measure_model_size_and_time(model, (1, 128, 128, 3))
# Out:
# Epoch 1/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.0032 - loss: 0.9646
# Epoch 1: val_dice_coef improved from -inf to 0.00000, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - dice_coef: 0.0031 - loss: 0.9645 - val_dice_coef: 1.1786e-10 - val_loss: 0.9592 - learning_rate: 0.0010
# Epoch 2/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 1.2591e-10 - loss: 0.9575
# Epoch 2: val_dice_coef did not improve from 0.00000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 1.2591e-10 - loss: 0.9574 - val_dice_coef: 1.1786e-10 - val_loss: 0.9555 - learning_rate: 0.0010
# Epoch 3/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 1.2574e-10 - loss: 0.9594
# Epoch 3: val_dice_coef did not improve from 0.00000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 1.2577e-10 - loss: 0.9594 - val_dice_coef: 1.1786e-10 - val_loss: 0.9563 - learning_rate: 0.0010
# Epoch 4/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 6.0528e-04 - loss: 0.9562
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
#
# Epoch 4: val_dice_coef did not improve from 0.00000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 6.4525e-04 - loss: 0.9561 - val_dice_coef: 1.1786e-10 - val_loss: 0.9560 - learning_rate: 0.0010
# Epoch 5/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 1.2662e-10 - loss: 0.9554
# Epoch 5: val_dice_coef did not improve from 0.00000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 1.2659e-10 - loss: 0.9554 - val_dice_coef: 1.1786e-10 - val_loss: 0.9554 - learning_rate: 9.0000e-04
# Epoch 6/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 1.2674e-10 - loss: 0.9551
# Epoch 6: val_dice_coef did not improve from 0.00000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 1.2673e-10 - loss: 0.9551 - val_dice_coef: 1.1786e-10 - val_loss: 0.9551 - learning_rate: 9.0000e-04
# Epoch 7/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 1.2561e-10 - loss: 0.9548
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
#
# Epoch 7: val_dice_coef did not improve from 0.00000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 1.2563e-10 - loss: 0.9548 - val_dice_coef: 1.1786e-10 - val_loss: 0.9550 - learning_rate: 9.0000e-04
# Epoch 8/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 1.2654e-10 - loss: 0.9546
# Epoch 8: val_dice_coef did not improve from 0.00000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 1.2654e-10 - loss: 0.9545 - val_dice_coef: 1.1786e-10 - val_loss: 0.9545 - learning_rate: 8.1000e-04
# Epoch 9/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 1.2476e-10 - loss: 0.9546
# Epoch 9: val_dice_coef did not improve from 0.00000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 1.2484e-10 - loss: 0.9545 - val_dice_coef: 1.1786e-10 - val_loss: 0.9545 - learning_rate: 8.1000e-04
# Epoch 10/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.0564 - loss: 0.9002
# Epoch 10: val_dice_coef improved from 0.00000 to 0.50117, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - dice_coef: 0.0631 - loss: 0.8939 - val_dice_coef: 0.5012 - val_loss: 0.4786 - learning_rate: 8.1000e-04
# Epoch 11/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.4503 - loss: 0.5255
# Epoch 11: val_dice_coef did not improve from 0.50117
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.4493 - loss: 0.5265 - val_dice_coef: 0.2902 - val_loss: 0.6787 - learning_rate: 8.1000e-04
# Epoch 12/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.4948 - loss: 0.4831
# Epoch 12: val_dice_coef did not improve from 0.50117
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.4971 - loss: 0.4809 - val_dice_coef: 0.4750 - val_loss: 0.5043 - learning_rate: 8.1000e-04
# Epoch 13/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.5978 - loss: 0.3849
# Epoch 13: val_dice_coef improved from 0.50117 to 0.60200, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - dice_coef: 0.5972 - loss: 0.3854 - val_dice_coef: 0.6020 - val_loss: 0.3831 - learning_rate: 8.1000e-04
# Epoch 14/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.6336 - loss: 0.3508
# Epoch 14: val_dice_coef improved from 0.60200 to 0.64050, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - dice_coef: 0.6332 - loss: 0.3512 - val_dice_coef: 0.6405 - val_loss: 0.3460 - learning_rate: 8.1000e-04
# Epoch 15/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.6378 - loss: 0.3466
# Epoch 15: val_dice_coef improved from 0.64050 to 0.66596, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - dice_coef: 0.6381 - loss: 0.3463 - val_dice_coef: 0.6660 - val_loss: 0.3216 - learning_rate: 8.1000e-04
# Epoch 16/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.6811 - loss: 0.3052
# Epoch 16: val_dice_coef improved from 0.66596 to 0.69129, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - dice_coef: 0.6809 - loss: 0.3054 - val_dice_coef: 0.6913 - val_loss: 0.2974 - learning_rate: 8.1000e-04
# Epoch 17/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.6776 - loss: 0.3086
# Epoch 17: val_dice_coef did not improve from 0.69129
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.6784 - loss: 0.3079 - val_dice_coef: 0.6866 - val_loss: 0.3019 - learning_rate: 8.1000e-04
# Epoch 18/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.6949 - loss: 0.2919
# Epoch 18: val_dice_coef did not improve from 0.69129
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.6952 - loss: 0.2917 - val_dice_coef: 0.6744 - val_loss: 0.3135 - learning_rate: 8.1000e-04
# Epoch 19/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.7422 - loss: 0.2467
# Epoch 19: val_dice_coef improved from 0.69129 to 0.69298, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - dice_coef: 0.7420 - loss: 0.2469 - val_dice_coef: 0.6930 - val_loss: 0.2957 - learning_rate: 8.1000e-04
# Epoch 20/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.7286 - loss: 0.2598
# Epoch 20: val_dice_coef improved from 0.69298 to 0.72237, saving model to best_unet_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - dice_coef: 0.7293 - loss: 0.2592 - val_dice_coef: 0.7224 - val_loss: 0.2676 - learning_rate: 8.1000e-04
# Epoch 21/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.7524 - loss: 0.2370
# Epoch 21: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.7523 - loss: 0.2371 - val_dice_coef: 0.6987 - val_loss: 0.2903 - learning_rate: 8.1000e-04
# Epoch 22/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.7789 - loss: 0.2116
# Epoch 22: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.7782 - loss: 0.2122 - val_dice_coef: 0.6738 - val_loss: 0.3143 - learning_rate: 8.1000e-04
# Epoch 23/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.7694 - loss: 0.2207
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0007290000503417104.
#
# Epoch 23: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.7686 - loss: 0.2215 - val_dice_coef: 0.6564 - val_loss: 0.3308 - learning_rate: 8.1000e-04
# Epoch 24/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.7743 - loss: 0.2160
# Epoch 24: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.7741 - loss: 0.2162 - val_dice_coef: 0.6709 - val_loss: 0.3170 - learning_rate: 7.2900e-04
# Epoch 25/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.7856 - loss: 0.2052
# Epoch 25: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.7855 - loss: 0.2053 - val_dice_coef: 0.6883 - val_loss: 0.3005 - learning_rate: 7.2900e-04
# Epoch 26/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.7797 - loss: 0.2109
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0006561000715009868.
#
# Epoch 26: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.7800 - loss: 0.2106 - val_dice_coef: 0.6765 - val_loss: 0.3116 - learning_rate: 7.2900e-04
# Epoch 27/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8096 - loss: 0.1823
# Epoch 27: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8091 - loss: 0.1828 - val_dice_coef: 0.6876 - val_loss: 0.3008 - learning_rate: 6.5610e-04
# Epoch 28/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8115 - loss: 0.1805
# Epoch 28: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8112 - loss: 0.1807 - val_dice_coef: 0.6954 - val_loss: 0.2938 - learning_rate: 6.5610e-04
# Epoch 29/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8132 - loss: 0.1788
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005904900433961303.
#
# Epoch 29: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8130 - loss: 0.1790 - val_dice_coef: 0.6741 - val_loss: 0.3142 - learning_rate: 6.5610e-04
# Epoch 30/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8264 - loss: 0.1663
# Epoch 30: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8260 - loss: 0.1666 - val_dice_coef: 0.6894 - val_loss: 0.2992 - learning_rate: 5.9049e-04
# Epoch 31/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8297 - loss: 0.1630
# Epoch 31: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.8296 - loss: 0.1631 - val_dice_coef: 0.6604 - val_loss: 0.3270 - learning_rate: 5.9049e-04
# Epoch 32/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8224 - loss: 0.1699
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005314410547725857.
#
# Epoch 32: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.8224 - loss: 0.1700 - val_dice_coef: 0.6998 - val_loss: 0.2896 - learning_rate: 5.9049e-04
# Epoch 33/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8369 - loss: 0.1560
# Epoch 33: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.8368 - loss: 0.1561 - val_dice_coef: 0.6871 - val_loss: 0.3016 - learning_rate: 5.3144e-04
# Epoch 34/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8305 - loss: 0.1622
# Epoch 34: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.8309 - loss: 0.1619 - val_dice_coef: 0.6572 - val_loss: 0.3302 - learning_rate: 5.3144e-04
# Epoch 35/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8394 - loss: 0.1537
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.00047829695977270604.
#
# Epoch 35: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.8390 - loss: 0.1541 - val_dice_coef: 0.6275 - val_loss: 0.3588 - learning_rate: 5.3144e-04
# Epoch 36/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8435 - loss: 0.1497
# Epoch 36: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.8435 - loss: 0.1498 - val_dice_coef: 0.6926 - val_loss: 0.2966 - learning_rate: 4.7830e-04
# Epoch 37/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8504 - loss: 0.1432
# Epoch 37: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8503 - loss: 0.1433 - val_dice_coef: 0.6627 - val_loss: 0.3253 - learning_rate: 4.7830e-04
# Epoch 38/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8576 - loss: 0.1363
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0004304672533180565.
#
# Epoch 38: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.8574 - loss: 0.1365 - val_dice_coef: 0.6549 - val_loss: 0.3328 - learning_rate: 4.7830e-04
# Epoch 39/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8586 - loss: 0.1353
# Epoch 39: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.8585 - loss: 0.1354 - val_dice_coef: 0.6568 - val_loss: 0.3310 - learning_rate: 4.3047e-04
# Epoch 40/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8607 - loss: 0.1333
# Epoch 40: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8605 - loss: 0.1335 - val_dice_coef: 0.6672 - val_loss: 0.3211 - learning_rate: 4.3047e-04
# Epoch 41/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8648 - loss: 0.1294
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.00038742052274756136.
#
# Epoch 41: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.8646 - loss: 0.1296 - val_dice_coef: 0.6684 - val_loss: 0.3204 - learning_rate: 4.3047e-04
# Epoch 42/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8755 - loss: 0.1192
# Epoch 42: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.8752 - loss: 0.1194 - val_dice_coef: 0.6612 - val_loss: 0.3269 - learning_rate: 3.8742e-04
# Epoch 43/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8714 - loss: 0.1231
# Epoch 43: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8713 - loss: 0.1232 - val_dice_coef: 0.6967 - val_loss: 0.2930 - learning_rate: 3.8742e-04
# Epoch 44/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8770 - loss: 0.1177
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0003486784757114947.
#
# Epoch 44: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.8769 - loss: 0.1178 - val_dice_coef: 0.6785 - val_loss: 0.3106 - learning_rate: 3.8742e-04
# Epoch 45/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8761 - loss: 0.1186
# Epoch 45: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8761 - loss: 0.1186 - val_dice_coef: 0.6134 - val_loss: 0.3731 - learning_rate: 3.4868e-04
# Epoch 46/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8531 - loss: 0.1406
# Epoch 46: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8537 - loss: 0.1400 - val_dice_coef: 0.6601 - val_loss: 0.3286 - learning_rate: 3.4868e-04
# Epoch 47/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8797 - loss: 0.1152
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.00031381062290165574.
#
# Epoch 47: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.8797 - loss: 0.1151 - val_dice_coef: 0.6546 - val_loss: 0.3335 - learning_rate: 3.4868e-04
# Epoch 48/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8816 - loss: 0.1133
# Epoch 48: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - dice_coef: 0.8815 - loss: 0.1134 - val_dice_coef: 0.6713 - val_loss: 0.3178 - learning_rate: 3.1381e-04
# Epoch 49/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8908 - loss: 0.1045
# Epoch 49: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8906 - loss: 0.1047 - val_dice_coef: 0.6658 - val_loss: 0.3230 - learning_rate: 3.1381e-04
# Epoch 50/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dice_coef: 0.8924 - loss: 0.1029
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0002824295632308349.
#
# Epoch 50: val_dice_coef did not improve from 0.72237
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - dice_coef: 0.8923 - loss: 0.1031 - val_dice_coef: 0.6661 - val_loss: 0.3229 - learning_rate: 3.1381e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# 모델의 파라미터 수: 1925601 (약 7.35 MB)
# 예측 시간: 0.3827 초

# %%
best_model = tf.keras.models.load_model('best_unet_model.keras', 
                                        custom_objects={'combined_loss': combined_loss,
                                                        'dice_coef': dice_coef})

test_loss, test_dice = best_model.evaluate(X_test, y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 424ms/step - dice_coef: 0.5912 - loss: 0.3912

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.subplot(1, 2, 2)
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('Model dice_coef')
plt.ylabel('dice_coef')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.tight_layout()
plt.show()

# %%
def visualize_results(model, X, y, num_samples=3):
    predictions = model.predict(X[:num_samples])
    predictions = (predictions > 0.5).astype(np.float32)
    plt.figure(figsize=(4*num_samples, 12))
    for i in range(num_samples):
        plt.subplot(3, num_samples, i + 1)
        plt.imshow(X[i])
        plt.title('Original Image')
        plt.axis('off')
        plt.subplot(3, num_samples, i + 1 + num_samples)
        plt.imshow(y[i, :, :, 0], cmap='gray')
        plt.title(f'True Mask\nDice: {dice_coef(y[i:i+1], predictions[i:i+1]).numpy():.4f}')
        plt.axis('off')
        plt.subplot(3, num_samples, i + 1 + 2*num_samples)
        plt.imshow(predictions[i, :, :, 0], cmap='gray')
        plt.title('Predicted Mask')
        plt.axis('off')
    plt.tight_layout()
    plt.show()

visualize_results(model, X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
